# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/ADMIN/OneDrive/Desktop/OASIS INTERNSHIP/5.Advertising.csv")

# %%
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
df.shape
# Out:
# (200, 5)

# %%
X = df.drop(['Unnamed: 0', 'Sales'], axis=1)

# %%
Y = df['Sales']

# %%
print (X)
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
print (Y)
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]>

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
#Train and test data
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size=0.7, random_state =2529)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(X_test)
print (Y_pred)
# Out:
# [21.02484412 17.1844544   4.64617036  6.10695785 10.0698345  20.87491079
#  12.59624763  9.0367768  11.0091622  13.72428997 15.19980413  9.95957803
#  17.06818378 21.06806289 17.5722449  16.56481033 18.32253633 13.09091582
#  17.48229697 20.42320768 13.50751722 19.55128166  8.60324952 16.62838011
#  11.9129386  20.45907262  3.9825543   9.57566552 13.41390303 16.47427136
#  23.90705057 13.11950517 11.47134261 19.06010491 11.86814456 10.14660767
#   5.38271226 12.14467837 15.19576743  8.90394268 12.86587269 13.00604829
#  14.34758329 16.07426293  7.94208848  9.68014891 22.6650952  19.49564999
#  18.06948385 21.55142697 14.2822412  23.09640331  4.7326212  23.07736683
#  14.22773341 20.42551731 11.4695548  16.57347566 22.91928883 23.56308167]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error
mean_absolute_error(Y_test, Y_pred)
# Out:
# 1.3900553266218718

# %%
mean_absolute_percentage_error(Y_test, Y_pred)
# Out:
# 0.11684507632823805

# %%
mean_squared_error(Y_test, Y_pred)
# Out:
# 3.055233185903398

# %%
corr = df.corr()
plt.subplots(figsize=(12,10))
sns.heatmap(corr, annot = True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(6,6))
sns.distplot(df['Unnamed: 0'])
plt.show()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_23692\3996485594.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Unnamed: 0'])

# %%
plt.figure(figsize=(6,6))
sns.distplot(df['TV'])
plt.show()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_23692\3581850763.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['TV'])

# %%
plt.figure(figsize=(6,6))
sns.distplot(df['Newspaper'])
plt.show()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_23692\2142078863.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Newspaper'])

# %%
plt.figure(figsize=(6,6))
sns.distplot(df['Radio'])
plt.show()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_23692\1651888035.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Radio'])
